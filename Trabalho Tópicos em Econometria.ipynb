# %%
import pandas as pd
import numpy as np
import statsmodels.api as sm
import statsmodels.formula.api as smf
import matplotlib.pyplot as plt

# %%
df = pd.read_excel('D:\Jupyter Notebook\ARTIGO TÓPÍCOS EM ECONOMETRIA\DadosJuntos.xlsx')
df
# Out:
#             Jogador Valor de Mercado                  Time Nacionalidade  \
# 0    Abel Hernández       2,80 mi. €         Internacional       Uruguai
# 1    Abner Vinícius        900 mil €  Athletico Paranaense        Brasil
# 2           Aderlan        475 mil €         RB Bragantino        Brasil
# 3         Adryelson        800 mil €                 Sport        Brasil
# 4     Alan Empereur        400 mil €             Palmeiras        Brasil
# ..              ...              ...                   ...           ...
# 560      Zé Gabriel        250 mil €         Internacional        Brasil
# 561       Zé Ivaldo        725 mil €  Athletico Paranaense        Brasil
# 562       Zé Rafael       3,50 mi. €             Palmeiras        Brasil
# 563      Zé Roberto        250 mil €   Atlético Goianiense        Brasil
# 564            Zeca       1,40 mi. €                 Bahia        Brasil
#
#      Idade       Posição  Nota SofaScore  Total played  Started  \
# 0       28  Centroavante            6.69            23       10
# 1       19  Lateral Esq.            7.02            34       30
# 2       28  Lateral Dir.            6.99            34       32
# 3       21      Zagueiro            6.87            36       36
# 4       25      Zagueiro            6.77            10        7
# ..     ...           ...             ...           ...      ...
# 560     20      Zagueiro            6.80            22       17
# 561     22      Zagueiro            6.72            14        6
# 562     26  Meia central            6.77            26       21
# 563     25  Centroavante            6.90            25       22
# 564     25  Lateral Esq.            6.59            11        4
#
#      Team of the week  ...  Possession won  Dribbled past per game  \
# 0                   0  ...             0.2                     0.1
# 1                   1  ...             0.1                     0.9
# 2                   3  ...             0.3                     2.1
# 3                   2  ...             0.0                     0.3
# 4                   0  ...             0.0                     0.0
# ..                ...  ...             ...                     ...
# 560                 0  ...             0.0                     0.7
# 561                 0  ...             0.1                     0.1
# 562                 1  ...             0.5                     1.8
# 563                 1  ...             0.4                     0.3
# 564                 0  ...             0.1                     0.5
#
#      Clearances per game  Succ, dribbles  Total duels won  Ground duels won  \
# 0                    0.3       0,2 (50%)        2,2 (37%)         1,1 (45%)
# 1                    1.1       0,6 (63%)        4,0 (49%)         3,2 (51%)
# 2                    1.2       1,0 (69%)        6,5 (53%)         4,7 (49%)
# 3                    5.6       0,1 (40%)        4,0 (58%)         1,1 (42%)
# 4                    2.9        0,0 (0%)        1,4 (40%)         0,7 (30%)
# ..                   ...             ...              ...               ...
# 560                  3.4       0,4 (80%)        3,5 (56%)         2,5 (59%)
# 561                  2.1        0,0 (0%)        1,6 (51%)         0,7 (34%)
# 562                  0.3       1,3 (65%)        5,7 (47%)         4,8 (47%)
# 563                  0.5       1,0 (59%)        6,4 (50%)         3,6 (52%)
# 564                  1.5       0,2 (40%)        0,6 (27%)         0,4 (21%)
#
#      Aerial duels won  Possession lost  Fouls  Was fouled
# 0           1,1 (31%)              4.5    0.6         0.5
# 1           0,8 (45%)             13.5    1.4         0.4
# 2           1,8 (65%)             15.8    1.9         0.9
# 3           2,9 (68%)              6.7    1.3         0.6
# 4           0,7 (58%)              5.1    1.4         0.5
# ..                ...              ...    ...         ...
# 560         1,0 (50%)              7.5    0.9         0.9
# 561         0,9 (81%)              5.3    0.9         0.1
# 562         0,9 (45%)              7.4    1.8         2.0
# 563         2,8 (47%)              8.6    1.8         2.2
# 564         0,3 (43%)              6.1    0.3         0.0
#
# [565 rows x 41 columns]

# %%
df1 = df.loc[df['Valor de Mercado'].str.contains('mil')]
df1['Valor de Mercado'] = df1['Valor de Mercado'].map(lambda x: x.rstrip('mil € mil.'))
df1['Valor de Mercado'] = df1['Valor de Mercado'].astype(float)
df1['Valor de Mercado'] = df1['Valor de Mercado'].values/1000
df1
# Out:
# <ipython-input-3-da1b42d27561>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['Valor de Mercado'] = df1['Valor de Mercado'].map(lambda x: x.rstrip('mil € mil.'))
# <ipython-input-3-da1b42d27561>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['Valor de Mercado'] = df1['Valor de Mercado'].astype(float)
# <ipython-input-3-da1b42d27561>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['Valor de Mercado'] = df1['Valor de Mercado'].values/1000
#             Jogador  Valor de Mercado                  Time Nacionalidade  \
# 1    Abner Vinícius             0.900  Athletico Paranaense        Brasil
# 2           Aderlan             0.475         RB Bragantino        Brasil
# 3         Adryelson             0.800                 Sport        Brasil
# 4     Alan Empereur             0.400             Palmeiras        Brasil
# 7           Alesson             0.350                 Bahia        Brasil
# ..              ...               ...                   ...           ...
# 557           Ytalo             0.325         RB Bragantino        Brasil
# 559      Yuri César             0.500             Fortaleza        Brasil
# 560      Zé Gabriel             0.250         Internacional        Brasil
# 561       Zé Ivaldo             0.725  Athletico Paranaense        Brasil
# 563      Zé Roberto             0.250   Atlético Goianiense        Brasil
#
#      Idade         Posição  Nota SofaScore  Total played  Started  \
# 1       19    Lateral Esq.            7.02            34       30
# 2       28    Lateral Dir.            6.99            34       32
# 3       21        Zagueiro            6.87            36       36
# 4       25        Zagueiro            6.77            10        7
# 7       20   Meia Ofensivo            6.78            16        3
# ..     ...             ...             ...           ...      ...
# 557     31    Centroavante            6.97            31       25
# 559     19  Ponta esquerda            6.76            28        8
# 560     20        Zagueiro            6.80            22       17
# 561     22        Zagueiro            6.72            14        6
# 563     25    Centroavante            6.90            25       22
#
#      Team of the week  ...  Possession won  Dribbled past per game  \
# 1                   1  ...             0.1                     0.9
# 2                   3  ...             0.3                     2.1
# 3                   2  ...             0.0                     0.3
# 4                   0  ...             0.0                     0.0
# 7                   0  ...             0.1                     0.7
# ..                ...  ...             ...                     ...
# 557                 2  ...             0.6                     0.5
# 559                 1  ...             0.1                     0.5
# 560                 0  ...             0.0                     0.7
# 561                 0  ...             0.1                     0.1
# 563                 1  ...             0.4                     0.3
#
#      Clearances per game  Succ, dribbles  Total duels won  Ground duels won  \
# 1                    1.1       0,6 (63%)        4,0 (49%)         3,2 (51%)
# 2                    1.2       1,0 (69%)        6,5 (53%)         4,7 (49%)
# 3                    5.6       0,1 (40%)        4,0 (58%)         1,1 (42%)
# 4                    2.9        0,0 (0%)        1,4 (40%)         0,7 (30%)
# 7                    0.0       0,8 (60%)        2,7 (39%)         2,6 (48%)
# ..                   ...             ...              ...               ...
# 557                  0.5       0,3 (73%)        2,3 (37%)         1,5 (47%)
# 559                  0.0       1,1 (61%)        3,1 (48%)         2,9 (55%)
# 560                  3.4       0,4 (80%)        3,5 (56%)         2,5 (59%)
# 561                  2.1        0,0 (0%)        1,6 (51%)         0,7 (34%)
# 563                  0.5       1,0 (59%)        6,4 (50%)         3,6 (52%)
#
#      Aerial duels won  Possession lost  Fouls  Was fouled
# 1           0,8 (45%)             13.5    1.4         0.4
# 2           1,8 (65%)             15.8    1.9         0.9
# 3           2,9 (68%)              6.7    1.3         0.6
# 4           0,7 (58%)              5.1    1.4         0.5
# 7            0,1 (5%)              4.4    0.7         0.6
# ..                ...              ...    ...         ...
# 557         0,8 (27%)              4.6    0.9         0.7
# 559         0,2 (16%)              5.5    0.8         1.3
# 560         1,0 (50%)              7.5    0.9         0.9
# 561         0,9 (81%)              5.3    0.9         0.1
# 563         2,8 (47%)              8.6    1.8         2.2
#
# [358 rows x 41 columns]

# %%
df2 = df.loc[~df['Valor de Mercado'].str.contains('mil')]
df2['Valor de Mercado'] = df2['Valor de Mercado'].map(lambda x: x.rstrip('mi. € mil.'))
df2['Valor de Mercado'] = df2['Valor de Mercado'].replace(',','.', regex=True).astype(float)
df2
# Out:
# <ipython-input-4-423f1ac15003>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Valor de Mercado'] = df2['Valor de Mercado'].map(lambda x: x.rstrip('mi. € mil.'))
# <ipython-input-4-423f1ac15003>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Valor de Mercado'] = df2['Valor de Mercado'].replace(',','.', regex=True).astype(float)
#               Jogador  Valor de Mercado              Time Nacionalidade  \
# 0      Abel Hernández               2.8     Internacional       Uruguai
# 5         Alan Franco               1.6  Atlético Mineiro       Equador
# 6          Alerrandro               1.6     RB Bragantino        Brasil
# 9              Alison               1.5            Santos        Brasil
# 10            Alisson               3.2            Grêmio        Brasil
# ..                ...               ...               ...           ...
# 553      Yago Pikachu               1.7             Vasco        Brasil
# 555  Yeferson Soteldo               8.0            Santos     Venezuela
# 558      Yuri Alberto               6.0     Internacional        Brasil
# 562         Zé Rafael               3.5         Palmeiras        Brasil
# 564              Zeca               1.4             Bahia        Brasil
#
#      Idade         Posição  Nota SofaScore  Total played  Started  \
# 0       28    Centroavante            6.69            23       10
# 5       20    Meia central            6.75            28       17
# 6       19    Centroavante            6.84            16       11
# 9       26         Volante            6.78            20       18
# 10      26   Ponta Direita            7.13            24       24
# ..     ...             ...             ...           ...      ...
# 553     27    Meia Direita            6.72            28       22
# 555     22  Ponta esquerda            7.08            24       20
# 558     18    Centroavante            6.95            23       14
# 562     26    Meia central            6.77            26       21
# 564     25    Lateral Esq.            6.59            11        4
#
#      Team of the week  ...  Possession won  Dribbled past per game  \
# 0                   0  ...             0.2                     0.1
# 5                   1  ...             0.3                     0.5
# 6                   1  ...             0.3                     0.5
# 9                   1  ...             0.1                     1.6
# 10                  2  ...             0.5                     1.0
# ..                ...  ...             ...                     ...
# 553                 1  ...             0.2                     0.8
# 555                 1  ...             0.6                     0.8
# 558                 1  ...             0.3                     0.2
# 562                 1  ...             0.5                     1.8
# 564                 0  ...             0.1                     0.5
#
#      Clearances per game  Succ, dribbles  Total duels won  Ground duels won  \
# 0                    0.3       0,2 (50%)        2,2 (37%)         1,1 (45%)
# 5                    0.3       0,2 (60%)        2,4 (42%)         1,9 (44%)
# 6                    0.4       0,4 (55%)        2,8 (42%)         2,0 (50%)
# 9                    1.3      0,3 (100%)        4,7 (49%)         3,6 (51%)
# 10                   0.5       1,8 (69%)        6,4 (53%)         5,2 (58%)
# ..                   ...             ...              ...               ...
# 553                  1.1       0,5 (54%)        3,8 (51%)         3,0 (54%)
# 555                  0.1       2,1 (59%)        4,7 (47%)         4,4 (50%)
# 558                  0.3       0,3 (41%)        3,6 (38%)         1,7 (35%)
# 562                  0.3       1,3 (65%)        5,7 (47%)         4,8 (47%)
# 564                  1.5       0,2 (40%)        0,6 (27%)         0,4 (21%)
#
#      Aerial duels won  Possession lost  Fouls  Was fouled
# 0           1,1 (31%)              4.5    0.6         0.5
# 5           0,5 (35%)              5.3    1.5         0.5
# 6           0,8 (29%)              6.2    0.6         1.3
# 9           1,1 (45%)              6.9    1.9         1.6
# 10          1,2 (38%)             13.0    1.2         2.9
# ..                ...              ...    ...         ...
# 553         0,7 (43%)             10.0    0.8         1.6
# 555         0,3 (26%)             15.2    0.8         2.0
# 558         1,9 (41%)              6.9    2.1         1.2
# 562         0,9 (45%)              7.4    1.8         2.0
# 564         0,3 (43%)              6.1    0.3         0.0
#
# [207 rows x 41 columns]

# %%
df3 = pd.merge(df1, df2, how = 'outer')
df3
# Out:
#               Jogador  Valor de Mercado                  Time Nacionalidade  \
# 0      Abner Vinícius             0.900  Athletico Paranaense        Brasil
# 1             Aderlan             0.475         RB Bragantino        Brasil
# 2           Adryelson             0.800                 Sport        Brasil
# 3       Alan Empereur             0.400             Palmeiras        Brasil
# 4             Alesson             0.350                 Bahia        Brasil
# ..                ...               ...                   ...           ...
# 560      Yago Pikachu             1.700                 Vasco        Brasil
# 561  Yeferson Soteldo             8.000                Santos     Venezuela
# 562      Yuri Alberto             6.000         Internacional        Brasil
# 563         Zé Rafael             3.500             Palmeiras        Brasil
# 564              Zeca             1.400                 Bahia        Brasil
#
#      Idade         Posição  Nota SofaScore  Total played  Started  \
# 0       19    Lateral Esq.            7.02            34       30
# 1       28    Lateral Dir.            6.99            34       32
# 2       21        Zagueiro            6.87            36       36
# 3       25        Zagueiro            6.77            10        7
# 4       20   Meia Ofensivo            6.78            16        3
# ..     ...             ...             ...           ...      ...
# 560     27    Meia Direita            6.72            28       22
# 561     22  Ponta esquerda            7.08            24       20
# 562     18    Centroavante            6.95            23       14
# 563     26    Meia central            6.77            26       21
# 564     25    Lateral Esq.            6.59            11        4
#
#      Team of the week  ...  Possession won  Dribbled past per game  \
# 0                   1  ...             0.1                     0.9
# 1                   3  ...             0.3                     2.1
# 2                   2  ...             0.0                     0.3
# 3                   0  ...             0.0                     0.0
# 4                   0  ...             0.1                     0.7
# ..                ...  ...             ...                     ...
# 560                 1  ...             0.2                     0.8
# 561                 1  ...             0.6                     0.8
# 562                 1  ...             0.3                     0.2
# 563                 1  ...             0.5                     1.8
# 564                 0  ...             0.1                     0.5
#
#      Clearances per game  Succ, dribbles  Total duels won  Ground duels won  \
# 0                    1.1       0,6 (63%)        4,0 (49%)         3,2 (51%)
# 1                    1.2       1,0 (69%)        6,5 (53%)         4,7 (49%)
# 2                    5.6       0,1 (40%)        4,0 (58%)         1,1 (42%)
# 3                    2.9        0,0 (0%)        1,4 (40%)         0,7 (30%)
# 4                    0.0       0,8 (60%)        2,7 (39%)         2,6 (48%)
# ..                   ...             ...              ...               ...
# 560                  1.1       0,5 (54%)        3,8 (51%)         3,0 (54%)
# 561                  0.1       2,1 (59%)        4,7 (47%)         4,4 (50%)
# 562                  0.3       0,3 (41%)        3,6 (38%)         1,7 (35%)
# 563                  0.3       1,3 (65%)        5,7 (47%)         4,8 (47%)
# 564                  1.5       0,2 (40%)        0,6 (27%)         0,4 (21%)
#
#      Aerial duels won  Possession lost  Fouls  Was fouled
# 0           0,8 (45%)             13.5    1.4         0.4
# 1           1,8 (65%)             15.8    1.9         0.9
# 2           2,9 (68%)              6.7    1.3         0.6
# 3           0,7 (58%)              5.1    1.4         0.5
# 4            0,1 (5%)              4.4    0.7         0.6
# ..                ...              ...    ...         ...
# 560         0,7 (43%)             10.0    0.8         1.6
# 561         0,3 (26%)             15.2    0.8         2.0
# 562         1,9 (41%)              6.9    2.1         1.2
# 563         0,9 (45%)              7.4    1.8         2.0
# 564         0,3 (43%)              6.1    0.3         0.0
#
# [565 rows x 41 columns]

# %%
df3['Valor de Mercado'] = df3['Valor de Mercado'].values*1000


df3['Accurate per game'] = df3['Accurate per game'].str[:4].replace(',','.', regex=True).astype(float)
df3['Acc, long balls'] = df3['Acc, long balls'].str[:4].replace(',','.', regex=True).astype(float)
df3['Acc, chipped passes'] = df3['Acc, chipped passes'].str[:4].replace(',','.', regex=True).astype(float)
df3['Acc, crosses'] = df3['Acc, crosses'].str[:4].replace(',','.', regex=True).astype(float)
df3['Succ, dribbles'] = df3['Succ, dribbles'].str[:4].replace(',','.', regex=True).astype(float)
df3['Total duels won'] = df3['Total duels won'].str[:4].replace(',','.', regex=True).astype(float)
df3['Ground duels won'] = df3['Ground duels won'].str[:4].replace(',','.', regex=True).astype(float)
df3['Aerial duels won'] = df3['Aerial duels won'].str[:4].replace(',','.', regex=True).astype(float)
df3['Acc, opposition half'] = df3['Acc, opposition half'].str[:4].replace(',','.', regex=True).astype(float)
df3['Acc, own half'] = df3['Acc, own half'].str[:4].replace(',','.', regex=True).astype(float)

df3['Idade'] = df3['Idade'].astype(float)
df3['Big chances created'] = df3['Big chances created'].astype(float)
df3['Assists'] = df3['Assists'].astype(float)
df3['Penalty won'] = df3['Penalty won'].astype(float)
df3['Big chances missed'] = df3['Big chances missed'].astype(float)
df3['Scoring frequency (Min)'] = df3['Scoring frequency (Min)'].astype(float)
df3['Goals'] = df3['Goals'].astype(float)
df3['Idade'] = df3['Idade'].astype(float)
df3['Team of the week'] = df3['Team of the week'].astype(float)
df3['Minutes per game'] = df3['Minutes per game'].astype(float)
df3['Total played'] = df3['Total played'].astype(float)
df3['Started'] = df3['Started'].astype(float)

df3 = df3.set_index('Jogador')

# %%
df3.dtypes
# Out:
# Valor de Mercado            float64
# Time                         object
# Nacionalidade                object
# Idade                       float64
# Posição                      object
# Nota SofaScore              float64
# Total played                float64
# Started                     float64
# Team of the week            float64
# Minutes per game            float64
# Goals                       float64
# Scoring frequency (Min)     float64
# Goals per game              float64
# Shots per game              float64
# Shots on target per game    float64
# Big chances missed          float64
# Goal conversion             float64
# Penalty won                 float64
# Assists                     float64
# Touches                     float64
# Big chances created         float64
# Key passes                  float64
# Accurate per game           float64
# Acc, own half               float64
# Acc, opposition half        float64
# Acc, long balls             float64
# Acc, chipped passes         float64
# Acc, crosses                float64
# Interceptions per game      float64
# Tackles per game            float64
# Possession won              float64
# Dribbled past per game      float64
# Clearances per game         float64
# Succ, dribbles              float64
# Total duels won             float64
# Ground duels won            float64
# Aerial duels won            float64
# Possession lost             float64
# Fouls                       float64
# Was fouled                  float64
# dtype: object

# %%
df3
# Out:
#                   Valor de Mercado                  Time Nacionalidade  Idade  \
# Jogador
# Abner Vinícius               900.0  Athletico Paranaense        Brasil   19.0
# Aderlan                      475.0         RB Bragantino        Brasil   28.0
# Adryelson                    800.0                 Sport        Brasil   21.0
# Alan Empereur                400.0             Palmeiras        Brasil   25.0
# Alesson                      350.0                 Bahia        Brasil   20.0
# ...                            ...                   ...           ...    ...
# Yago Pikachu                1700.0                 Vasco        Brasil   27.0
# Yeferson Soteldo            8000.0                Santos     Venezuela   22.0
# Yuri Alberto                6000.0         Internacional        Brasil   18.0
# Zé Rafael                   3500.0             Palmeiras        Brasil   26.0
# Zeca                        1400.0                 Bahia        Brasil   25.0
#
#                          Posição  Nota SofaScore  Total played  Started  \
# Jogador
# Abner Vinícius      Lateral Esq.            7.02          34.0     30.0
# Aderlan             Lateral Dir.            6.99          34.0     32.0
# Adryelson               Zagueiro            6.87          36.0     36.0
# Alan Empereur           Zagueiro            6.77          10.0      7.0
# Alesson            Meia Ofensivo            6.78          16.0      3.0
# ...                          ...             ...           ...      ...
# Yago Pikachu        Meia Direita            6.72          28.0     22.0
# Yeferson Soteldo  Ponta esquerda            7.08          24.0     20.0
# Yuri Alberto        Centroavante            6.95          23.0     14.0
# Zé Rafael           Meia central            6.77          26.0     21.0
# Zeca                Lateral Esq.            6.59          11.0      4.0
#
#                   Team of the week  Minutes per game  ...  Possession won  \
# Jogador                                               ...
# Abner Vinícius                 1.0              83.0  ...             0.1
# Aderlan                        3.0              84.0  ...             0.3
# Adryelson                      2.0              89.0  ...             0.0
# Alan Empereur                  0.0              70.0  ...             0.0
# Alesson                        0.0              23.0  ...             0.1
# ...                            ...               ...  ...             ...
# Yago Pikachu                   1.0              71.0  ...             0.2
# Yeferson Soteldo               1.0              79.0  ...             0.6
# Yuri Alberto                   1.0              58.0  ...             0.3
# Zé Rafael                      1.0              64.0  ...             0.5
# Zeca                           0.0              41.0  ...             0.1
#
#                   Dribbled past per game  Clearances per game  Succ, dribbles  \
# Jogador
# Abner Vinícius                       0.9                  1.1             0.6
# Aderlan                              2.1                  1.2             1.0
# Adryelson                            0.3                  5.6             0.1
# Alan Empereur                        0.0                  2.9             0.0
# Alesson                              0.7                  0.0             0.8
# ...                                  ...                  ...             ...
# Yago Pikachu                         0.8                  1.1             0.5
# Yeferson Soteldo                     0.8                  0.1             2.1
# Yuri Alberto                         0.2                  0.3             0.3
# Zé Rafael                            1.8                  0.3             1.3
# Zeca                                 0.5                  1.5             0.2
#
#                   Total duels won  Ground duels won  Aerial duels won  \
# Jogador
# Abner Vinícius                4.0               3.2               0.8
# Aderlan                       6.5               4.7               1.8
# Adryelson                     4.0               1.1               2.9
# Alan Empereur                 1.4               0.7               0.7
# Alesson                       2.7               2.6               0.1
# ...                           ...               ...               ...
# Yago Pikachu                  3.8               3.0               0.7
# Yeferson Soteldo              4.7               4.4               0.3
# Yuri Alberto                  3.6               1.7               1.9
# Zé Rafael                     5.7               4.8               0.9
# Zeca                          0.6               0.4               0.3
#
#                   Possession lost  Fouls  Was fouled
# Jogador
# Abner Vinícius               13.5    1.4         0.4
# Aderlan                      15.8    1.9         0.9
# Adryelson                     6.7    1.3         0.6
# Alan Empereur                 5.1    1.4         0.5
# Alesson                       4.4    0.7         0.6
# ...                           ...    ...         ...
# Yago Pikachu                 10.0    0.8         1.6
# Yeferson Soteldo             15.2    0.8         2.0
# Yuri Alberto                  6.9    2.1         1.2
# Zé Rafael                     7.4    1.8         2.0
# Zeca                          6.1    0.3         0.0
#
# [565 rows x 40 columns]

# %%
df3.columns
# Out:
# Index(['Valor de Mercado', 'Time', 'Nacionalidade', 'Idade', 'Posição',
#        'Nota SofaScore', 'Total played', 'Started', 'Team of the week',
#        'Minutes per game', 'Goals', 'Scoring frequency (Min)',
#        'Goals per game', 'Shots per game', 'Shots on target per game',
#        'Big chances missed', 'Goal conversion', 'Penalty won', 'Assists',
#        'Touches', 'Big chances created', 'Key passes', 'Accurate per game',
#        'Acc, own half', 'Acc, opposition half', 'Acc, long balls',
#        'Acc, chipped passes', 'Acc, crosses', 'Interceptions per game',
#        'Tackles per game', 'Possession won', 'Dribbled past per game',
#        'Clearances per game', 'Succ, dribbles', 'Total duels won',
#        'Ground duels won', 'Aerial duels won', 'Possession lost', 'Fouls',
#        'Was fouled'],
#       dtype='object')

# %%
df3 = df3.rename(columns={'Valor de Mercado': 'ValorDeMercado', 'Posição': 'Posicao', 'Nota SofaScore': 'NotaSofaScore',
                         'Total played': 'TotalPlayed', 'Team of the week': 'TeamOfTheWeek', 'Minutes per game': 'MinutesPerGame',
                         'Scoring frequency (Min)': 'ScoringFrequencyMin', 'Goals per game': 'GoalsPerGame', 'Shots per game': 'ShotsPerGame',
                         'Shots on target per game': 'ShotsOnTargetPerGame', 'Big chances missed': 'BigChancesMissed', 'Key passes': 'KeyPasses',
                         'Accurate per game': 'AccuratePerGame', 'Acc, long balls': 'AccLongBalls', 'Acc, chipped passes': 'AccChippedPasses', 'Acc, crosses': 'AccCrosses', 
                         'Interceptions per game': 'InterceptionsPerGame', 'Tackles per game': 'TacklesPerGame', 'Possession won': 'PossessionWonPerGame', 'Dribbled past per game': 'DribbledPastPerGame',
                         'Clearances per game': 'ClearancesPerGame', 'Succ, dribbles': 'SuccDribbles', 'Total duels won': 'TotalDuelsWon', 'Ground duels won': 'GroundDuelsWon'
                         ,'Aerial duels won': 'AerialDuelsWon','Possession lost': 'PossessionLost','Was fouled': 'WasFouled'})

# %%
valores = {'Lateral Esq.': 'Lateral', 'Lateral Dir.': 'Lateral', 'Meio-Campo': 'Meia Ofensivo', 'Meia Direita': 'Lateral'
          ,'Atacante': 'Centroavante', 'Meia Esquerda': 'Ponta', 'Ponta Direita': 'Ponta', 'Ponta esquerda': 'Ponta',
           'Zagueiro': 'Zagueiro','Volante': 'Volante','Centroavante': 'Centroavante','Meia Ofensivo': 'Meia Ofensivo','Meia central': 'Meia Central'}

df3['Posicao'] = df3['Posicao'].map(valores)

# %%
#ValorDeMercado Posicao NotaSofaScore TotalPlayed TeamOfTheWeek MinutesPerGame ScoringFrequencyMin GoalsPerGame ShotsPerGame ShotsOnTargetPerGame BigChancesMissed KeyPassesAccuratePerGame AccLongBalls AccChippedPasses AccCrosses InterceptionsPerGame TacklesPerGame PossessionWonPerGame DribbledPastPerGame
#ClearancesPerGame SuccDribbles TotalDuelsWon GroundDuelsWon AerialDuelsWon PossessionLost WasFouled

# %%
time_dummies = pd.get_dummies(df3['Time'])
nacionalidade_dummies = pd.get_dummies(df3['Nacionalidade'])
posicao_dummies = pd.get_dummies(df3['Posicao'])

df3 = pd.concat([df3,time_dummies],axis = 1)
df3 = pd.concat([df3,nacionalidade_dummies],axis = 1)
df3 = pd.concat([df3,posicao_dummies],axis = 1)

# %%
df3.drop(['Time', 'Nacionalidade', 'Posicao'], axis=1, inplace=True)

# %%
df3.columns
# Out:
# Index(['ValorDeMercado', 'Idade', 'NotaSofaScore', 'TotalPlayed', 'Started',
#        'TeamOfTheWeek', 'MinutesPerGame', 'Goals', 'ScoringFrequencyMin',
#        'GoalsPerGame', 'ShotsPerGame', 'ShotsOnTargetPerGame',
#        'BigChancesMissed', 'Goal conversion', 'Penalty won', 'Assists',
#        'Touches', 'Big chances created', 'KeyPasses', 'AccuratePerGame',
#        'Acc, own half', 'Acc, opposition half', 'AccLongBalls',
#        'AccChippedPasses', 'AccCrosses', 'InterceptionsPerGame',
#        'TacklesPerGame', 'PossessionWonPerGame', 'DribbledPastPerGame',
#        'ClearancesPerGame', 'SuccDribbles', 'TotalDuelsWon', 'GroundDuelsWon',
#        'AerialDuelsWon', 'PossessionLost', 'Fouls', 'WasFouled',
#        'Athletico Paranaense', 'Atlético Goianiense', 'Atlético Mineiro',
#        'Bahia', 'Botafogo', 'Ceará', 'Corinthians', 'Coritiba', 'Flamengo',
#        'Fluminense', 'Fortaleza', 'Goiás', 'Grêmio', 'Internacional',
#        'Palmeiras', 'RB Bragantino', 'Santos', 'Sport', 'São Paulo', 'Vasco',
#        'Argentina', 'Brasil', 'Chile', 'Colômbia', 'Coreia do Sul',
#        'Costa do Marfim', 'EUA', 'Equador', 'Espanha', 'Itália', 'Japão',
#        'Paraguai', 'Perú', 'Portugal', 'Uruguai', 'Venezuela', 'Centroavante',
#        'Lateral', 'Meia Central', 'Meia Ofensivo', 'Ponta', 'Volante',
#        'Zagueiro'],
#       dtype='object')

# %%
colunas = ['Idade', 'NotaSofaScore', 'TotalPlayed', 'Started',
       'TeamOfTheWeek', 'MinutesPerGame', 'Goals', 'ScoringFrequencyMin',
       'GoalsPerGame', 'ShotsPerGame', 'ShotsOnTargetPerGame',
       'BigChancesMissed', 'Goal conversion', 'Penalty won', 'Assists',
       'Touches', 'Big chances created', 'KeyPasses', 'AccuratePerGame',
       'Acc, own half', 'Acc, opposition half', 'AccLongBalls',
       'AccChippedPasses', 'AccCrosses', 'InterceptionsPerGame',
       'TacklesPerGame', 'PossessionWonPerGame', 'DribbledPastPerGame',
       'ClearancesPerGame', 'SuccDribbles', 'TotalDuelsWon', 'GroundDuelsWon',
       'AerialDuelsWon', 'PossessionLost', 'Fouls', 'WasFouled',
       'Athletico Paranaense', 'Atlético Goianiense', 'Atlético Mineiro',
       'Bahia', 'Botafogo', 'Ceará', 'Corinthians', 'Coritiba', 'Flamengo',
       'Fluminense', 'Fortaleza', 'Goiás', 'Grêmio', 'Internacional',
       'Palmeiras', 'RB Bragantino', 'Santos', 'Sport', 'São Paulo', 'Vasco',
       'Argentina', 'Brasil', 'Chile', 'Colômbia', 'Coreia do Sul',
       'Costa do Marfim', 'EUA', 'Equador', 'Espanha', 'Itália', 'Japão',
       'Paraguai', 'Perú', 'Portugal', 'Uruguai', 'Venezuela', 'Centroavante',
       'Lateral', 'Meia Central', 'Meia Ofensivo', 'Ponta', 'Volante',
       'Zagueiro']

# %%
df3
# Out:
#                   ValorDeMercado  Idade  NotaSofaScore  TotalPlayed  Started  \
# Jogador
# Abner Vinícius             900.0   19.0           7.02         34.0     30.0
# Aderlan                    475.0   28.0           6.99         34.0     32.0
# Adryelson                  800.0   21.0           6.87         36.0     36.0
# Alan Empereur              400.0   25.0           6.77         10.0      7.0
# Alesson                    350.0   20.0           6.78         16.0      3.0
# ...                          ...    ...            ...          ...      ...
# Yago Pikachu              1700.0   27.0           6.72         28.0     22.0
# Yeferson Soteldo          8000.0   22.0           7.08         24.0     20.0
# Yuri Alberto              6000.0   18.0           6.95         23.0     14.0
# Zé Rafael                 3500.0   26.0           6.77         26.0     21.0
# Zeca                      1400.0   25.0           6.59         11.0      4.0
#
#                   TeamOfTheWeek  MinutesPerGame  Goals  ScoringFrequencyMin  \
# Jogador
# Abner Vinícius              1.0            83.0    3.0                944.0
# Aderlan                     3.0            84.0    0.0                  0.0
# Adryelson                   2.0            89.0    0.0                  0.0
# Alan Empereur               0.0            70.0    0.0                  0.0
# Alesson                     0.0            23.0    2.0                183.0
# ...                         ...             ...    ...                  ...
# Yago Pikachu                1.0            71.0    2.0                994.0
# Yeferson Soteldo            1.0            79.0    4.0                475.0
# Yuri Alberto                1.0            58.0   10.0                132.0
# Zé Rafael                   1.0            64.0    2.0                836.0
# Zeca                        0.0            41.0    1.0                453.0
#
#                   GoalsPerGame  ...  Portugal  Uruguai  Venezuela  \
# Jogador                         ...
# Abner Vinícius             0.1  ...         0        0          0
# Aderlan                    0.0  ...         0        0          0
# Adryelson                  0.0  ...         0        0          0
# Alan Empereur              0.0  ...         0        0          0
# Alesson                    0.1  ...         0        0          0
# ...                        ...  ...       ...      ...        ...
# Yago Pikachu               0.1  ...         0        0          0
# Yeferson Soteldo           0.2  ...         0        0          1
# Yuri Alberto               0.4  ...         0        0          0
# Zé Rafael                  0.1  ...         0        0          0
# Zeca                       0.1  ...         0        0          0
#
#                   Centroavante  Lateral  Meia Central  Meia Ofensivo  Ponta  \
# Jogador
# Abner Vinícius               0        1             0              0      0
# Aderlan                      0        1             0              0      0
# Adryelson                    0        0             0              0      0
# Alan Empereur                0        0             0              0      0
# Alesson                      0        0             0              1      0
# ...                        ...      ...           ...            ...    ...
# Yago Pikachu                 0        1             0              0      0
# Yeferson Soteldo             0        0             0              0      1
# Yuri Alberto                 1        0             0              0      0
# Zé Rafael                    0        0             1              0      0
# Zeca                         0        1             0              0      0
#
#                   Volante  Zagueiro
# Jogador
# Abner Vinícius          0         0
# Aderlan                 0         0
# Adryelson               0         1
# Alan Empereur           0         1
# Alesson                 0         0
# ...                   ...       ...
# Yago Pikachu            0         0
# Yeferson Soteldo        0         0
# Yuri Alberto            0         0
# Zé Rafael               0         0
# Zeca                    0         0
#
# [565 rows x 80 columns]

# %%
df3.drop(['Coreia do Sul','Brasil','Flamengo','Ponta'],axis=1, inplace=True)

# %%
corr = df3.corr()
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style  type="text/css" >
# #T_becdf_row0_col0,#T_becdf_row1_col1,#T_becdf_row2_col2,#T_becdf_row3_col3,#T_becdf_row4_col4,#T_becdf_row5_col5,#T_becdf_row6_col6,#T_becdf_row7_col7,#T_becdf_row8_col8,#T_becdf_row9_col9,#T_becdf_row10_col10,#T_becdf_row11_col11,#T_becdf_row12_col12,#T_becdf_row13_col13,#T_becdf_row14_col14,#T_becdf_row15_col15,#T_becdf_row16_col16,#T_becdf_row17_col17,#T_becdf_row18_col18,#T_becdf_row19_col19,#T_becdf_row20_col20,#T_becdf_row21_col21,#T_becdf_row22_col22,#T_becdf_row23_col23,#T_becdf_row24_col24,#T_becdf_row25_col25,#T_becdf_row26_col26,#T_becdf_row27_col27,#T_becdf_row28_col28,#T_becdf_row29_col29,#T_becdf_row30_col30,#T_becdf_row31_col31,#T_becdf_row32_col32,#T_becdf_row33_col33,#T_becdf_row34_col34,#T_becdf_row35_col35,#T_becdf_row36_col36,#T_becdf_row37_col37,#T_becdf_row38_col38,#T_becdf_row39_col39,#T_becdf_row40_col40,#T_becdf_row41_col41,#T_becdf_row42_col42,#T_becdf_row43_col43,#T_becdf_row44_col44,#T_becdf_row45_col45,#T_becdf_row46_col46,#T_becdf_row47_col47,#T_becdf_row48_col48,#T_becdf_row49_col49,#T_becdf_row50_col50,#T_becdf_row51_col51,#T_becdf_row52_col52,#T_becdf_row53_col53,#T_becdf_row54_col54,#T_becdf_row55_col55,#T_becdf_row56_col56,#T_becdf_row57_col57,#T_becdf_row58_col58,#T_becdf_row59_col59,#T_becdf_row60_col60,#T_becdf_row61_col61,#T_becdf_row62_col62,#T_becdf_row63_col63,#T_becdf_row64_col64,#T_becdf_row65_col65,#T_becdf_row66_col66,#T_becdf_row67_col67,#T_becdf_row68_col68,#T_becdf_row69_col69,#T_becdf_row70_col70,#T_becdf_row71_col71,#T_becdf_row72_col72,#T_becdf_row73_col73,#T_becdf_row74_col74,#T_becdf_row75_col75{
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }#T_becdf_row0_col1,#T_becdf_row3_col45,#T_becdf_row4_col62,#T_becdf_row5_col61,#T_becdf_row5_col74,#T_becdf_row7_col49,#T_becdf_row7_col72,#T_becdf_row8_col45,#T_becdf_row10_col54,#T_becdf_row11_col40,#T_becdf_row12_col54,#T_becdf_row13_col49,#T_becdf_row13_col66,#T_becdf_row14_col56,#T_becdf_row14_col61,#T_becdf_row15_col45,#T_becdf_row15_col49,#T_becdf_row17_col61,#T_becdf_row18_col49,#T_becdf_row20_col46,#T_becdf_row22_col11,#T_becdf_row23_col9,#T_becdf_row23_col55,#T_becdf_row24_col37,#T_becdf_row24_col43,#T_becdf_row24_col44,#T_becdf_row24_col61,#T_becdf_row24_col75,#T_becdf_row28_col44,#T_becdf_row28_col57,#T_becdf_row28_col69,#T_becdf_row29_col18,#T_becdf_row30_col41,#T_becdf_row30_col51,#T_becdf_row31_col65,#T_becdf_row34_col39,#T_becdf_row34_col41,#T_becdf_row36_col38,#T_becdf_row40_col13,#T_becdf_row45_col0,#T_becdf_row45_col68,#T_becdf_row46_col5,#T_becdf_row49_col58,#T_becdf_row54_col13,#T_becdf_row57_col2,#T_becdf_row57_col4,#T_becdf_row58_col7,#T_becdf_row58_col53,#T_becdf_row59_col31,#T_becdf_row60_col0,#T_becdf_row60_col8,#T_becdf_row60_col41,#T_becdf_row61_col47,#T_becdf_row62_col8,#T_becdf_row62_col41,#T_becdf_row63_col41,#T_becdf_row65_col13,#T_becdf_row67_col41,#T_becdf_row69_col1,#T_becdf_row70_col55,#T_becdf_row71_col51,#T_becdf_row72_col40,#T_becdf_row73_col48,#T_becdf_row73_col54,#T_becdf_row75_col3,#T_becdf_row75_col55{
#             background-color:  #536edd;
#             color:  #000000;
#         }#T_becdf_row0_col2,#T_becdf_row1_col70,#T_becdf_row7_col21,#T_becdf_row9_col4,#T_becdf_row10_col16,#T_becdf_row13_col3,#T_becdf_row17_col8,#T_becdf_row21_col33,#T_becdf_row23_col1,#T_becdf_row31_col12,#T_becdf_row35_col3,#T_becdf_row49_col25,#T_becdf_row50_col19,#T_becdf_row54_col16,#T_becdf_row68_col26,#T_becdf_row72_col16,#T_becdf_row72_col27{
#             background-color:  #a5c3fe;
#             color:  #000000;
#         }#T_becdf_row0_col3,#T_becdf_row0_col24,#T_becdf_row1_col10,#T_becdf_row11_col73,#T_becdf_row14_col16,#T_becdf_row17_col22,#T_becdf_row22_col1,#T_becdf_row25_col3,#T_becdf_row26_col33,#T_becdf_row31_col14,#T_becdf_row34_col14,#T_becdf_row36_col8,#T_becdf_row38_col29,#T_becdf_row39_col22,#T_becdf_row44_col29,#T_becdf_row46_col29,#T_becdf_row47_col75,#T_becdf_row50_col29,#T_becdf_row52_col25,#T_becdf_row52_col70,#T_becdf_row57_col27,#T_becdf_row62_col25,#T_becdf_row64_col73,#T_becdf_row65_col23,#T_becdf_row71_col22,#T_becdf_row71_col28{
#             background-color:  #9abbff;
#             color:  #000000;
#         }#T_becdf_row0_col4,#T_becdf_row1_col7,#T_becdf_row1_col9,#T_becdf_row4_col0,#T_becdf_row9_col28,#T_becdf_row10_col8,#T_becdf_row17_col25,#T_becdf_row18_col1,#T_becdf_row19_col30,#T_becdf_row20_col5,#T_becdf_row23_col30,#T_becdf_row28_col71,#T_becdf_row35_col8,#T_becdf_row38_col25,#T_becdf_row39_col10,#T_becdf_row41_col25,#T_becdf_row41_col75,#T_becdf_row43_col19,#T_becdf_row44_col20,#T_becdf_row44_col26,#T_becdf_row49_col20,#T_becdf_row49_col34,#T_becdf_row51_col16,#T_becdf_row51_col70,#T_becdf_row51_col75,#T_becdf_row53_col27,#T_becdf_row53_col75,#T_becdf_row55_col19,#T_becdf_row55_col20,#T_becdf_row55_col30,#T_becdf_row56_col26,#T_becdf_row59_col29,#T_becdf_row60_col22,#T_becdf_row63_col28,#T_becdf_row64_col23,#T_becdf_row64_col28,#T_becdf_row67_col19,#T_becdf_row67_col29,#T_becdf_row69_col36{
#             background-color:  #8fb1fe;
#             color:  #000000;
#         }#T_becdf_row0_col5,#T_becdf_row0_col23,#T_becdf_row3_col70,#T_becdf_row5_col33,#T_becdf_row5_col75,#T_becdf_row9_col6,#T_becdf_row21_col11,#T_becdf_row27_col6,#T_becdf_row32_col20,#T_becdf_row32_col71,#T_becdf_row45_col26,#T_becdf_row45_col29,#T_becdf_row48_col30,#T_becdf_row50_col23,#T_becdf_row55_col70,#T_becdf_row55_col75,#T_becdf_row68_col30,#T_becdf_row72_col20,#T_becdf_row72_col25,#T_becdf_row73_col11{
#             background-color:  #9bbcff;
#             color:  #000000;
#         }#T_becdf_row0_col6,#T_becdf_row0_col22,#T_becdf_row1_col3,#T_becdf_row2_col70,#T_becdf_row3_col1,#T_becdf_row17_col70,#T_becdf_row18_col25,#T_becdf_row23_col36,#T_becdf_row23_col74,#T_becdf_row29_col71,#T_becdf_row35_col71,#T_becdf_row37_col29,#T_becdf_row38_col75,#T_becdf_row39_col25,#T_becdf_row39_col30,#T_becdf_row40_col70,#T_becdf_row43_col16,#T_becdf_row43_col70,#T_becdf_row44_col75,#T_becdf_row45_col30,#T_becdf_row45_col75,#T_becdf_row46_col30,#T_becdf_row47_col26,#T_becdf_row48_col29,#T_becdf_row49_col75,#T_becdf_row50_col21,#T_becdf_row50_col70,#T_becdf_row51_col30,#T_becdf_row54_col30,#T_becdf_row55_col16,#T_becdf_row56_col28,#T_becdf_row57_col19,#T_becdf_row60_col19,#T_becdf_row63_col22,#T_becdf_row63_col30,#T_becdf_row64_col20,#T_becdf_row64_col26,#T_becdf_row69_col15,#T_becdf_row69_col16,#T_becdf_row72_col30,#T_becdf_row73_col21{
#             background-color:  #92b4fe;
#             color:  #000000;
#         }#T_becdf_row0_col7,#T_becdf_row2_col12,#T_becdf_row6_col30,#T_becdf_row13_col27,#T_becdf_row19_col28,#T_becdf_row23_col24,#T_becdf_row26_col3,#T_becdf_row27_col2,#T_becdf_row28_col4,#T_becdf_row33_col4,#T_becdf_row33_col35,#T_becdf_row35_col4,#T_becdf_row36_col12,#T_becdf_row73_col27{
#             background-color:  #bed2f6;
#             color:  #000000;
#         }#T_becdf_row0_col8,#T_becdf_row1_col32,#T_becdf_row8_col14,#T_becdf_row9_col19,#T_becdf_row12_col73,#T_becdf_row13_col22,#T_becdf_row13_col35,#T_becdf_row20_col65,#T_becdf_row24_col0,#T_becdf_row24_col29,#T_becdf_row31_col1,#T_becdf_row33_col32,#T_becdf_row39_col74,#T_becdf_row40_col28,#T_becdf_row42_col34,#T_becdf_row43_col10,#T_becdf_row45_col33,#T_becdf_row47_col63,#T_becdf_row48_col17,#T_becdf_row50_col34,#T_becdf_row52_col15,#T_becdf_row53_col36,#T_becdf_row55_col24,#T_becdf_row56_col10,#T_becdf_row57_col9,#T_becdf_row59_col73,#T_becdf_row60_col11,#T_becdf_row60_col24,#T_becdf_row60_col73,#T_becdf_row62_col11,#T_becdf_row62_col73,#T_becdf_row63_col6,#T_becdf_row63_col73,#T_becdf_row66_col24,#T_becdf_row67_col24,#T_becdf_row67_col73,#T_becdf_row68_col71,#T_becdf_row72_col29,#T_becdf_row74_col70{
#             background-color:  #7699f6;
#             color:  #000000;
#         }#T_becdf_row0_col9,#T_becdf_row1_col22,#T_becdf_row4_col24,#T_becdf_row5_col20,#T_becdf_row11_col3,#T_becdf_row20_col34,#T_becdf_row23_col33,#T_becdf_row24_col26,#T_becdf_row29_col26,#T_becdf_row30_col3,#T_becdf_row34_col29,#T_becdf_row71_col21{
#             background-c

# %%
df3
# Out:
#                   ValorDeMercado  Idade  NotaSofaScore  TotalPlayed  Started  \
# Jogador
# Abner Vinícius             900.0   19.0           7.02         34.0     30.0
# Aderlan                    475.0   28.0           6.99         34.0     32.0
# Adryelson                  800.0   21.0           6.87         36.0     36.0
# Alan Empereur              400.0   25.0           6.77         10.0      7.0
# Alesson                    350.0   20.0           6.78         16.0      3.0
# ...                          ...    ...            ...          ...      ...
# Yago Pikachu              1700.0   27.0           6.72         28.0     22.0
# Yeferson Soteldo          8000.0   22.0           7.08         24.0     20.0
# Yuri Alberto              6000.0   18.0           6.95         23.0     14.0
# Zé Rafael                 3500.0   26.0           6.77         26.0     21.0
# Zeca                      1400.0   25.0           6.59         11.0      4.0
#
#                   TeamOfTheWeek  MinutesPerGame  Goals  ScoringFrequencyMin  \
# Jogador
# Abner Vinícius              1.0            83.0    3.0                944.0
# Aderlan                     3.0            84.0    0.0                  0.0
# Adryelson                   2.0            89.0    0.0                  0.0
# Alan Empereur               0.0            70.0    0.0                  0.0
# Alesson                     0.0            23.0    2.0                183.0
# ...                         ...             ...    ...                  ...
# Yago Pikachu                1.0            71.0    2.0                994.0
# Yeferson Soteldo            1.0            79.0    4.0                475.0
# Yuri Alberto                1.0            58.0   10.0                132.0
# Zé Rafael                   1.0            64.0    2.0                836.0
# Zeca                        0.0            41.0    1.0                453.0
#
#                   GoalsPerGame  ...  Perú  Portugal  Uruguai  Venezuela  \
# Jogador                         ...
# Abner Vinícius             0.1  ...     0         0        0          0
# Aderlan                    0.0  ...     0         0        0          0
# Adryelson                  0.0  ...     0         0        0          0
# Alan Empereur              0.0  ...     0         0        0          0
# Alesson                    0.1  ...     0         0        0          0
# ...                        ...  ...   ...       ...      ...        ...
# Yago Pikachu               0.1  ...     0         0        0          0
# Yeferson Soteldo           0.2  ...     0         0        0          1
# Yuri Alberto               0.4  ...     0         0        0          0
# Zé Rafael                  0.1  ...     0         0        0          0
# Zeca                       0.1  ...     0         0        0          0
#
#                   Centroavante  Lateral  Meia Central  Meia Ofensivo  Volante  \
# Jogador
# Abner Vinícius               0        1             0              0        0
# Aderlan                      0        1             0              0        0
# Adryelson                    0        0             0              0        0
# Alan Empereur                0        0             0              0        0
# Alesson                      0        0             0              1        0
# ...                        ...      ...           ...            ...      ...
# Yago Pikachu                 0        1             0              0        0
# Yeferson Soteldo             0        0             0              0        0
# Yuri Alberto                 1        0             0              0        0
# Zé Rafael                    0        0             1              0        0
# Zeca                         0        1             0              0        0
#
#                   Zagueiro
# Jogador
# Abner Vinícius           0
# Aderlan                  0
# Adryelson                1
# Alan Empereur            1
# Alesson                  0
# ...                    ...
# Yago Pikachu             0
# Yeferson Soteldo         0
# Yuri Alberto             0
# Zé Rafael                0
# Zeca                     0
#
# [565 rows x 76 columns]

# %%
df3.to_excel('D:\Jupyter Notebook\ARTIGO TÓPÍCOS EM ECONOMETRIA\DadosTrabalhoFinal6.xlsx', index = False)
